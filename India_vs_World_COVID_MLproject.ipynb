# %% [markdown]
# ##Importing all the necessary libraries

# %%
#Importing the required libraries
import pandas as pd

#Visualisation libraries
import matplotlib.pyplot as plt
#%matplotlib inline
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import folium
from folium import plugins

#Diable the current warnings
import warnings
warnings.filterwarnings('ignore')

#Manipulating the default plot size
plt.rcParams['figure.figsize'] = 10, 12

# %%
#Learn how to read a .xls file by creating a dataframe using pandas
#Reading the datasets

df = pd.read_excel('Covid cases in India.xlsx')
df_india = df.copy()
print(df)
# Out:
#     S. No. Name of State / UT  ...  Cured  Death
# 0        1     Andhra Pradesh  ...      0      0
# 1        2              Bihar  ...      0      1
# 2        3       Chhattisgarh  ...      0      0
# 3        4              Delhi  ...      6      1
# 4        5            Gujarat  ...      0      1
# 5        6            Haryana  ...     11      0
# 6        7   Himachal Pradesh  ...      0      1
# 7        8          Karnataka  ...      3      1
# 8        9             Kerala  ...      4      0
# 9       10     Madhya Pradesh  ...      0      0
# 10      11        Maharashtra  ...      0      2
# 11      12            Manipur  ...      0      0
# 12      13            Mizoram  ...      0      0
# 13      14             Odisha  ...      0      0
# 14      15         Puducherry  ...      0      0
# 15      16             Punjab  ...      0      1
# 16      17          Rajasthan  ...      3      0
# 17      18         Tamil Nadu  ...      1      0
# 18      19          Telengana  ...      1      0
# 19      20         Chandigarh  ...      0      0
# 20      21  Jammu and Kashmir  ...      1      0
# 21      22             Ladakh  ...      0      0
# 22      23      Uttar Pradesh  ...     11      0
# 23      24        Uttarakhand  ...      0      0
# 24      25        West Bengal  ...      0      1
#
# [25 rows x 6 columns]

# %%
#Coordinates of Indian States and Union Territories
India_coord = pd.read_excel('Indian Coordinates.xlsx')
print(India_coord)
# Out:
#                       Name of State / UT   Latitude  Longitude
# 0                   Andaman And Nicobar   11.667026  92.735983
# 1                         Andhra Pradesh  14.750429  78.570026
# 2                     Arunachal Pradesh   27.100399  93.616601
# 3                                 Assam   26.749981  94.216667
# 4                                 Bihar   25.785414  87.479973
# 5                            Chandigarh   30.719997  76.780006
# 6                          Chhattisgarh   22.090420  82.159987
# 7                Dadra And Nagar Haveli   20.266578  73.016618
# 8                                  Delhi  28.669993  77.230004
# 9                                   Goa   15.491997  73.818001
# 10                               Haryana  28.450006  77.019991
# 11                     Himachal Pradesh   31.100025  77.166597
# 12  Union Territory of Jammu and Kashmir  33.450000  76.240000
# 13                            Jharkhand   23.800393  86.419986
# 14                             Karnataka  12.570381  76.919997
# 15                                Kerala   8.900373  76.569993
# 16                          Lakshadweep   10.562573  72.636867
# 17                       Madhya Pradesh   21.300391  76.130019
# 18                           Maharashtra  19.250232  73.160175
# 19                              Manipur   24.799971  93.950017
# 20                            Meghalaya   25.570492  91.880014
# 21                              Mizoram   23.710399  92.720015
# 22                             Nagaland   25.666998  94.116570
# 23                               Orissa   19.820430  85.900017
# 24                           Puducherry   11.934994  79.830000
# 25                                Punjab  31.519974  75.980003
# 26                             Rajasthan  26.449999  74.639981
# 27                               Sikkim   27.333330  88.616647
# 28                             Telengana  18.112400  79.019300
# 29                            Tamil Nadu  12.920386  79.150042
# 30                              Tripura   23.835404  91.279999
# 31                         Uttar Pradesh  27.599981  78.050006
# 32                           Uttarakhand  30.320409  78.050006
# 33                          West Bengal   22.580390  88.329947
# 34             Union Territory of Ladakh  34.100000  77.340000

# %%
#Day by day data of India, Korea, Italy and Wuhan
dbd_India = pd.read_excel('per_day_cases.xlsx',parse_dates=True, sheet_name='India')
dbd_Italy = pd.read_excel('per_day_cases.xlsx',parse_dates=True, sheet_name="Italy")
dbd_Korea = pd.read_excel('per_day_cases.xlsx',parse_dates=True, sheet_name="Korea")
dbd_Wuhan = pd.read_excel('per_day_cases.xlsx',parse_dates=True, sheet_name="Wuhan")

# %%
#Total cases is the total nuber of cases (Indian National + Foregin National)
df.drop(['S. No.'],axis=1,inplace=True)
df['Total cases'] = df['Total Confirmed cases (Indian National)'] + df['Total Confirmed cases ( Foreign National )']
total_cases = df['Total cases'].sum()
print('\nTotal number of confirmed COVID 2019 cases across India till date (22nd March, 2020):', total_cases)
# Out:
# Total number of confirmed COVID 2019 cases across India till date (22nd March, 2020): 562

# %%
df.style.background_gradient(cmap = 'Greens')
# Out:
# <style  type="text/css" >
# #T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row0_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row9_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row24_col1{
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row0_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row0_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row0_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row1_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row1_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row2_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row2_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row2_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row2_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row2_col5,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row4_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row5_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row6_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row6_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row7_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row8_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row9_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row9_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row9_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row10_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row11_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row11_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row11_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row11_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row11_col5,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row12_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row12_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row12_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row12_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row12_col5,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row13_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row13_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row13_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row14_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row14_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row14_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row14_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row14_col5,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row15_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row15_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row16_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row17_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row18_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row19_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row19_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row19_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row20_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row20_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row21_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row21_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row21_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row22_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row23_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row23_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row24_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row24_col3{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row0_col5,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row3_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row4_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row9_col5,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row22_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row23_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row24_col5{
#             background-color:  #edf8e9;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row1_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row6_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row23_col1{
#             background-color:  #f4fbf2;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row1_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row3_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row4_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row6_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row7_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row15_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row24_col4{
#             background-color:  #73c476;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row1_col5,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row6_col5{
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row3_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row16_col1{
#             background-color:  #bbe4b4;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row3_col3{
#             background-color:  #62bb6d;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row3_col5,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row15_col1{
#             background-color:  #bee5b8;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row4_col1{
#             background-color:  #b5e1ae;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row4_col5{
#             background-color:  #bae3b3;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row5_col1{
#             background-color:  #e4f5df;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row5_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row5_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row8_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row8_col5,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row10_col4,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row22_col3{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row5_col5{
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row7_col1{
#             background-color:  #98d594;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row7_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row16_col3{
#             background-color:  #c1e6ba;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row7_col5{
#             background-color:  #a3da9d;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row8_col2{
#             background-color:  #56b567;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row8_col3{
#             background-color:  #a4da9e;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row10_col1{
#             background-color:  #004d1f;
#             color:  #f1f1f1;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row10_col2{
#             background-color:  #d0edca;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row10_col5{
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row13_col1,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row13_col5{
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row15_col5{
#             background-color:  #c4e8bd;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row16_col2,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row17_col2{
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row16_col5{
#             background-color:  #bce4b5;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row17_col1{
#             background-color:  #dff3da;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row17_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row18_col3,#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row20_col3{
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row17_col5{
#             background-color:  #ddf2d8;
#             color:  #000000;
#         }#T_a6e3d722_2f41_11eb_aa64_0242ac1c0002row18_col1{
#             background-color:  #

# %%
#Total Active is total cases - (Number of death + Cured)
df['Total Active'] = df['Total cases'] - (df['Death']+ df['Cured'])
total_active = df['Total Active'].sum()
print('Total number number of active cases across India = ', total_active)

tot_cases = df.groupby('Name of State / UT')['Total Active'].sum().sort_values(ascending=False).to_frame()
tot_cases.style.background_gradient(cmap='Greens')
# Out:
# Total number number of active cases across India =  512
# <style  type="text/css" >
# #T_fd170400_2f4d_11eb_aa64_0242ac1c0002row0_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row1_col0{
#             background-color:  #005622;
#             color:  #f1f1f1;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row2_col0{
#             background-color:  #aadda4;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row3_col0{
#             background-color:  #b2e0ac;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row4_col0{
#             background-color:  #b8e3b2;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row5_col0{
#             background-color:  #c2e7bb;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row6_col0{
#             background-color:  #c4e8bd;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row7_col0,#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row8_col0{
#             background-color:  #ceecc8;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row9_col0,#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row10_col0{
#             background-color:  #def2d9;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row11_col0{
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row12_col0,#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row13_col0{
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row14_col0{
#             background-color:  #edf8ea;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row15_col0{
#             background-color:  #eff9ec;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row16_col0{
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row17_col0{
#             background-color:  #f3faf0;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row18_col0,#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row19_col0,#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row20_col0{
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row21_col0,#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row22_col0,#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row23_col0,#T_fd170400_2f4d_11eb_aa64_0242ac1c0002row24_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Active</th>    </tr>    <tr>        <th class="index_name level0" >Name of State / UT</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row0" class="row_heading level0 row0" >Kerala</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row0_col0" class="data row0 col0" >105</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row1" class="row_heading level0 row1" >Maharashtra</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row1_col0" class="data row1 col0" >99</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row2" class="row_heading level0 row2" >Karnataka</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row2_col0" class="data row2 col0" >37</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row3" class="row_heading level0 row3" >Telengana</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row3_col0" class="data row3 col0" >34</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row4" class="row_heading level0 row4" >Gujarat</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row4_col0" class="data row4 col0" >32</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row5" class="row_heading level0 row5" >Rajasthan</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row5_col0" class="data row5 col0" >29</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row6" class="row_heading level0 row6" >Punjab</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row6_col0" class="data row6 col0" >28</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row7" class="row_heading level0 row7" >Uttar Pradesh</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row7_col0" class="data row7 col0" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row8" class="row_heading level0 row8" >Delhi</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row8_col0" class="data row8 col0" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row9" class="row_heading level0 row9" >Tamil Nadu</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row9_col0" class="data row9 col0" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row10" class="row_heading level0 row10" >Haryana</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row10_col0" class="data row10 col0" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row11" class="row_heading level0 row11" >Ladakh</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row11_col0" class="data row11 col0" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row12" class="row_heading level0 row12" >Madhya Pradesh</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row12_col0" class="data row12 col0" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row13" class="row_heading level0 row13" >Andhra Pradesh</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row13_col0" class="data row13 col0" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row14" class="row_heading level0 row14" >West Bengal</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row14_col0" class="data row14 col0" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row15" class="row_heading level0 row15" >Chandigarh</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row15_col0" class="data row15 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row16" class="row_heading level0 row16" >Jammu and Kashmir</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row16_col0" class="data row16 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002level0_row17" class="row_heading level0 row17" >Uttarakhand</th>
#                         <td id="T_fd170400_2f4d_11eb_aa64_0242ac1c0002row17_col0" class="data row17 col0" >4</td>
#             </tr>
#             <

# %%
 #learn how to use folium to create a zoomable map
 df_fullmap = pd.merge(India_coord, df, on='Name of State / UT')
 map = folium.Map(location=[30, 100], zoom_start=4, tiles='Stamenterrain')

for lat, lon, value, name in zip(df_fullmap['Latitude'], df_fullmap['Longitude'], df_fullmap['Total cases'], df_fullmap['Name of State / UT']):
  folium.CircleMarker([lat, lon],
      radius=value*0.7,
    popup=('<strong>State/strong>: ' +str(name).capitalize() + '<br>''<strong>Total Cases</strong>: ' + str(value) + '<br>'),
    color='red',
    fill_color='red',
    fill_opacity=0.2 ).add_to(map)    
map


# # Learn how to use folium to create a zoomable map
# df_full = pd.merge(India_coord,df,on='Name of State / UT')
# map = folium.Map(location=[20, 70], zoom_start=4,tiles='Stamenterrain')

# for lat, lon, value, name in zip(df_full['Latitude'], df_full['Longitude'], df_full['Total cases'], df_full['Name of State / UT']):
#     folium.CircleMarker([lat, lon], 
#                         radius=value*0.8, 
#                         popup = ('<strong>State</strong>: ' + str(name).capitalize() + '<br>''<strong>Total Cases</strong>: ' + str(value) + '<br>'),
#                         color='red',
#                         fill_color='red',
#                         fill_opacity=0.3 ).add_to(map)
# map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
